# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
Raw_DIR= r'D:\project\Data Analysis\Drowsiness Detection Model\mrlEyes_2018_01'
for dirpath, dirname, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i, dst=r'D:\project\Data Analysis\Drowsiness Detection Model\MRL Eye Data\Prepared_Data\Close Eyes')
        
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i, dst=r'D:\project\Data Analysis\Drowsiness Detection Model\MRL Eye Data\Prepared_Data\Open Eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [02:40<00:00, 63.97it/s]
